# %% [markdown]
# # UI Usability Fixes Applied
#
# - Date: 2026-03-13
# - Source audit: `reports/ui_usability_audit.ipynb`
# - Status: All listed audit findings addressed in code.

# %% [markdown]
# ## 1) Contrast + Typography Readability
# - Increased muted/disabled text contrast:
#   - `textMuted`: `#666666` -> `#9A9A9A`
#   - `textDisabled`: `#3A3A3A` -> `#6A6A6A`
# - Raised baseline small text sizes in design tokens:
#   - `GText.label`: 11 -> 12
#   - `GText.muted`: 12 -> 13
#   - `GText.danger`: 12 -> 13
# - Updated theme small text defaults to avoid 10px body labels.
#
# Files:
# - `lib/core/constants.dart`
# - `lib/core/theme.dart`

# %% [markdown]
# ## 2) Dark-Only Restriction Removed
# - Added persisted theme preference (`system`, `light`, `dark`).
# - Added provider/state notifier for theme mode.
# - Wired `MaterialApp` to respect selected theme mode.
# - Added profile UI control to change theme mode.
#
# Files:
# - `lib/services/local_db.dart`
# - `lib/services/providers.dart`
# - `lib/core/theme.dart`
# - `lib/main.dart`
# - `lib/pages/profile_page.dart`

# %% [markdown]
# ## 3) Gesture-Only Interactions Replaced with Semantic Controls
# - Replaced `GestureDetector`-based controls with `InkWell` / `TextButton` / `IconButton` for better semantics and accessibility behavior.
# - Verified no remaining `GestureDetector` usages in `lib/pages` + `lib/core`.
#
# Files touched:
# - `lib/pages/login_page.dart`
# - `lib/pages/signup_page.dart`
# - `lib/pages/verify_opt_page.dart`
# - `lib/pages/anchor_page.dart`
# - `lib/pages/daily3_page.dart`
# - `lib/pages/responsibility_page.dart`
# - `lib/pages/add_tasks.dart`
# - `lib/pages/add_persons.dart`

# %% [markdown]
# ## 4) Copy Tone Normalization
# - Removed archaic copy and normalized to plain, modern language.
# - Updated responsibility/add-person/habit warning messaging for consistency.
#
# File:
# - `lib/core/constants.dart`

# %% [markdown]
# ## 5) Previously Flagged UX Safety Fixes (Already Applied)
# - Capture delete now supports Undo.
# - OTP field uses OTP-specific hint.
#
# Files:
# - `lib/pages/capture_page.dart`
# - `lib/services/providers.dart`
# - `lib/pages/verify_opt_page.dart`
# - `lib/core/constants.dart`

# %% [markdown]
# ## Validation
# - `flutter analyze --no-pub` passed with no issues.
